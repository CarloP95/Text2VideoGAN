# %% [markdown]
# # Training MoCoGAN
#
# In this notebook, the process of using the class Trainer will be explained and the training of MoCoGAN will be carried on as if the `newTrain.py` script would be launched from Console.

# %% [markdown]
# ## Import Models and Dataloading
# First, let's import classes from `models` and `dataloading` modules.
#
# Then let's create the dataloader and define the clParameters.

# %%
import sys
sys.path.append('./mocogan')

# %%
from mocogan.dataloading import DataLoaderFactory, Transformator
from mocogan.models      import UCF_101, Discriminator_I, VideoDiscriminator, VideoGenerator

def createModels(parameters, dict_For_Classes = None):

    n_classes  = len(parameters['classes'])

    n_channels = 3
    dim_z_content=50                                            #  dimensionality of the content input, ie hidden space [default: 50]
    dim_z_motion=10                                             #  dimensionality of the motion input [default: 10]
    dim_z_category= n_classes if n_classes > 0 else 101         #  dimensionality of categorical input [default: 101]
    video_lenght = 16                                           #  hyperparameter T of the mocogan [default: 16]
    cuda = parameters['cuda']

    return Discriminator_I(), VideoDiscriminator(n_channels, dim_z_category, cuda = cuda), \
                 VideoGenerator(n_channels, dim_z_content, dim_z_category, dim_z_motion, video_lenght, cuda, class_to_idx = dict_For_Classes)


img_size          = 96
max_frame         = 16
mean              = (100.99800554447337/255, 96.7195209000943/255, 89.63882431650443/255)
std               = (72.07041943699456/255, 70.41506399740703/255, 71.55581999303428/255)

batch_size        = 16
classes           = ['Biking', 'HorseRace', 'HorseRiding', 'Bowling', 'IceDancing']
preprocessing     = 0
cuda              = 1
soft_labels       = True
random_labels     = True
shuffle_labels    = True
i_wasserstein     = 5
n_iter            = 100
i_log_stat        = 1
pre_train_epoch   = 0
i_save_weights    = i_wasserstein
i_alternate_train = 2



parameters = {
        "cuda"              : cuda,
        "batch_size"        : batch_size,
        "soft_labels"       : soft_labels,
        "n_iter"            : n_iter,
        "classes"           : classes,
        "i_log_stat"        : i_log_stat,
        "pre_train_epoch"   : pre_train_epoch,
        "i_save_weights"    : i_save_weights,
        "i_alternate_train" : i_alternate_train,
        "preprocessed"      : preprocessing,
        "random_labels"     : random_labels,
        "shuffle_labels"    : shuffle_labels,
        "i_wasserstein"     : i_wasserstein
    }





transformator = Transformator(img_size, max_frame, medium= mean, stdDev= std)
dataloader    = DataLoaderFactory(UCF_101, transformator, preprocessing, batch_size, classes = classes).getDataLoader()

dis_i, dis_v, gen = createModels(parameters, dataloader.dataset.class_to_idx)

gen.init_weigths()
# Out:
# /home/carlo/anaconda3/lib/python3.6/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %% [markdown]
# ## Create the Trainer
# Let's import and use the Trainer Object to train the networks.

# %%
from mocogan.trainer import Trainer

trainer = Trainer(parameters, dis_i, dis_v, gen, dataloader, transformator)

# %% [markdown]
# ## Start Training
# Finally, let's start training process in the `Trainer`

# %%
trainer.train()
# Out:
# Batch [45/45] Loss_Di: 1.1356 Loss_Dv: 1.8988 Accuracy_Dv: 0.5625 Loss_Gen: 0.0000
# [1/100] (0d 0h 3m 18s) Loss_Di: 1.2626 Loss_Dv: 2.4158 Accuracy_Dv: 0.4639 Loss_Generator: 3.0266
# Batch [45/45] Loss_Di: 0.7337 Loss_Dv: 1.6259 Accuracy_Dv: 0.5625 Loss_Gen: 0.0000
# [2/100] (0d 0h 6m 48s) Loss_Di: 0.9326 Loss_Dv: 1.6695 Accuracy_Dv: 0.5694 Loss_Generator: 3.0215
# Batch [45/45] Loss_Di: 0.4908 Loss_Dv: 1.6827 Accuracy_Dv: 0.5000 Loss_Gen: 0.0000
# [3/100] (0d 0h 10m 13s) Loss_Di: 0.6240 Loss_Dv: 1.4974 Accuracy_Dv: 0.5556 Loss_Generator: 2.7066
# Batch [45/45] Loss_Di: 0.3142 Loss_Dv: 1.2262 Accuracy_Dv: 0.6875 Loss_Gen: 0.0000
# [4/100] (0d 0h 13m 33s) Loss_Di: 0.4946 Loss_Dv: 1.4383 Accuracy_Dv: 0.5750 Loss_Generator: 2.3793
# Batch [45/45] Loss_Di: 0.3828 Loss_Dv: 1.1352 Accuracy_Dv: 0.6875 Loss_Gen: 0.0000
# [5/100] (0d 0h 16m 51s) Loss_Di: 0.4236 Loss_Dv: 1.3835 Accuracy_Dv: 0.5861 Loss_Generator: 1.9519
# Batch [45/45] Loss_Di: 0.3982 Loss_Dv: 1.0709 Accuracy_Dv: 0.8125 Loss_Gen: 0.0000
# [6/100] (0d 0h 20m 17s) Loss_Di: 0.3825 Loss_Dv: 1.3359 Accuracy_Dv: 0.6181 Loss_Generator: 1.4841
# Batch [45/45] Loss_Di: 0.2649 Loss_Dv: 1.3203 Accuracy_Dv: 0.5000 Loss_Gen: 0.0000
# [7/100] (0d 0h 23m 37s) Loss_Di: 0.3706 Loss_Dv: 1.2702 Accuracy_Dv: 0.6389 Loss_Generator: 1.3520
# Batch [45/45] Loss_Di: 0.2513 Loss_Dv: 1.2915 Accuracy_Dv: 0.5000 Loss_Gen: 0.0000
# [8/100] (0d 0h 27m 6s) Loss_Di: 0.3706 Loss_Dv: 1.3069 Accuracy_Dv: 0.6292 Loss_Generator: 1.2160
# Batch [45/45] Loss_Di: 0.1961 Loss_Dv: 1.1792 Accuracy_Dv: 0.5625 Loss_Gen: 0.0000
# [9/100] (0d 0h 30m 27s) Loss_Di: 0.2289 Loss_Dv: 1.1188 Accuracy_Dv: 0.6389 Loss_Generator: 0.8499
# Batch [45/45] Loss_Di: 0.2169 Loss_Dv: 1.1996 Accuracy_Dv: 0.6250 Loss_Gen: 0.0000
# [10/100] (0d 0h 33m 49s) Loss_Di: 0.2158 Loss_Dv: 1.0941 Accuracy_Dv: 0.6597 Loss_Generator: 0.7772
# Batch [45/45] Loss_Di: 0.2022 Loss_Dv: 0.8924 Accuracy_Dv: 0.8125 Loss_Gen: 0.0000
# [11/100] (0d 0h 37m 17s) Loss_Di: 0.2126 Loss_Dv: 1.0746 Accuracy_Dv: 0.6667 Loss_Generator: 0.7509
# Batch [45/45] Loss_Di: 0.2244 Loss_Dv: 1.2497 Accuracy_Dv: 0.7500 Loss_Gen: 0.0000
# [12/100] (0d 0h 40m 41s) Loss_Di: 0.2143 Loss_Dv: 1.0224 Accuracy_Dv: 0.6736 Loss_Generator: 0.7273
# Batch [45/45] Loss_Di: 0.1908 Loss_Dv: 0.4632 Accuracy_Dv: 0.9375 Loss_Gen: 0.0000
# [79/100] (0d 4h 30m 27s) Loss_Di: 0.1977 Loss_Dv: 0.5793 Accuracy_Dv: 0.8556 Loss_Generator: 0.6545
# Batch [45/45] Loss_Di: 0.2102 Loss_Dv: 0.7765 Accuracy_Dv: 0.8125 Loss_Gen: 0.0000
# [80/100] (0d 4h 33m 47s) Loss_Di: 0.1975 Loss_Dv: 0.5928 Accuracy_Dv: 0.8694 Loss_Generator: 0.6191
# Batch [45/45] Loss_Di: 0.1844 Loss_Dv: 0.4769 Accuracy_Dv: 0.8750 Loss_Gen: 0.0000
# [81/100] (0d 4h 37m 21s) Loss_Di: 0.1994 Loss_Dv: 0.5589 Accuracy_Dv: 0.8833 Loss_Generator: 0.5254
# Batch [45/45] Loss_Di: 0.2007 Loss_Dv: 0.3431 Accuracy_Dv: 1.0000 Loss_Gen: 0.0000
# [82/100] (0d 4h 40m 48s) Loss_Di: 0.1991 Loss_Dv: 0.5776 Accuracy_Dv: 0.8528 Loss_Generator: 0.5165
# Batch [45/45] Loss_Di: 0.2043 Loss_Dv: 0.6440 Accuracy_Dv: 0.8750 Loss_Gen: 0.0000
# [83/100] (0d 4h 44m 13s) Loss_Di: 0.2015 Loss_Dv: 0.5724 Accuracy_Dv: 0.8556 Loss_Generator: 0.4890
# Batch [45/45] Loss_Di: 0.1823 Loss_Dv: 0.3364 Accuracy_Dv: 1.0000 Loss_Gen: 0.0000
# [84/100] (0d 4h 47m 43s) Loss_Di: 0.2036 Loss_Dv: 0.5215 Accuracy_Dv: 0.8875 Loss_Generator: 0.4887
# Batch [45/45] Loss_Di: 0.1935 Loss_Dv: 0.8653 Accuracy_Dv: 0.6875 Loss_Gen: 0.0000
# [85/100] (0d 4h 51m 8s) Loss_Di: 0.2006 Loss_Dv: 0.6002 Accuracy_Dv: 0.8542 Loss_Generator: 0.4661
# Batch [45/45] Loss_Di: 0.1918 Loss_Dv: 0.3987 Accuracy_Dv: 1.0000 Loss_Gen: 0.0000
# [86/100] (0d 4h 54m 36s) Loss_Di: 0.2012 Loss_Dv: 0.5478 Accuracy_Dv: 0.8861 Loss_Generator: 0.4432
# Batch [45/45] Loss_Di: 0.2246 Loss_Dv: 0.4770 Accuracy_Dv: 0.9375 Loss_Gen: 0.0000
# [87/100] (0d 4h 57m 55s) Loss_Di: 0.1995 Loss_Dv: 0.5450 Accuracy_Dv: 0.8722 Loss_Generator: 0.4483
# Batch [45/45] Loss_Di: 0.1596 Loss_Dv: 0.5739 Accuracy_Dv: 0.8750 Loss_Gen: 0.0000
# [88/100] (0d 5h 1m 24s) Loss_Di: 0.2010 Loss_Dv: 0.5510 Accuracy_Dv: 0.8667 Loss_Generator: 0.4495
# Batch [45/45] Loss_Di: 0.1924 Loss_Dv: 0.5874 Accuracy_Dv: 0.8750 Loss_Gen: 0.0000
# [89/100] (0d 5h 5m 0s) Loss_Di: 0.2015 Loss_Dv: 0.5356 Accuracy_Dv: 0.8875 Loss_Generator: 0.4559
# Batch [45/45] Loss_Di: 0.1989 Loss_Dv: 0.6112 Accuracy_Dv: 0.6875 Loss_Gen: 0.0000
# [90/100] (0d 5h 8m 25s) Loss_Di: 0.2001 Loss_Dv: 0.5457 Accuracy_Dv: 0.8694 Loss_Generator: 0.4557
# Batch [45/45] Loss_Di: 0.2132 Loss_Dv: 0.4645 Accuracy_Dv: 0.8750 Loss_Gen: 0.0000
# [91/100] (0d 5h 11m 48s) Loss_Di: 0.1973 Loss_Dv: 0.5202 Accuracy_Dv: 0.8986 Loss_Generator: 0.4244
# Batch [45/45] Loss_Di: 0.1973 Loss_Dv: 0.5942 Accuracy_Dv: 0.8750 Loss_Gen: 0.0000
# [92/100] (0d 5h 15m 11s) Loss_Di: 0.1958 Loss_Dv: 0.5367 Accuracy_Dv: 0.8833 Loss_Generator: 0.4186
# Batch [45/45] Loss_Di: 0.1823 Loss_Dv: 0.3729 Accuracy_Dv: 1.0000 Loss_Gen: 0.0000
# [93/100] (0d 5h 18m 33s) Loss_Di: 0.1968 Loss_Dv: 0.5399 Accuracy_Dv: 0.8653 Loss_Generator: 0.4046
# Batch [45/45] Loss_Di: 0.1561 Loss_Dv: 0.4568 Accuracy_Dv: 0.9375 Loss_Gen: 0.0000
# [94/100] (0d 5h 21m 59s) Loss_Di: 0.2017 Loss_Dv: 0.5697 Accuracy_Dv: 0.8736 Loss_Generator: 0.4327
# Batch [45/45] Loss_Di: 0.1827 Loss_Dv: 0.7350 Accuracy_Dv: 0.8125 Loss_Gen: 0.0000
# [95/100] (0d 5h 25m 27s) Loss_Di: 0.1988 Loss_Dv: 0.5607 Accuracy_Dv: 0.8708 Loss_Generator: 0.4246
# Batch [45/45] Loss_Di: 0.2076 Loss_Dv: 0.6686 Accuracy_Dv: 0.8125 Loss_Gen: 0.0000
# [96/100] (0d 5h 28m 48s) Loss_Di: 0.1986 Loss_Dv: 0.5642 Accuracy_Dv: 0.8750 Loss_Generator: 0.4181
# Batch [45/45] Loss_Di: 0.1877 Loss_Dv: 0.3617 Accuracy_Dv: 1.0000 Loss_Gen: 0.0000
# [97/100] (0d 5h 32m 11s) Loss_Di: 0.1993 Loss_Dv: 0.5407 Accuracy_Dv: 0.8764 Loss_Generator: 0.4393
# Batch [45/45] Loss_Di: 0.1847 Loss_Dv: 0.3711 Accuracy_Dv: 1.0000 Loss_Gen: 0.0000
# [98/100] (0d 5h 35m 35s) Loss_Di: 0.1987 Loss_Dv: 0.5181 Accuracy_Dv: 0.8736 Loss_Generator: 0.4219
# Batch [45/45] Loss_Di: 0.2058 Loss_Dv: 0.4829 Accuracy_Dv: 0.9375 Loss_Gen: 0.0000
# [99/100] (0d 5h 38m 57s) Loss_Di: 0.1995 Loss_Dv: 0.5077 Accuracy_Dv: 0.8861 Loss_Generator: 0.4125
# Batch [45/45] Loss_Di: 0.1997 Loss_Dv: 0.8023 Accuracy_Dv: 0.8125 Loss_Gen: 0.0000
# [100/100] (0d 5h 42m 18s) Loss_Di: 0.1966 Loss_Dv: 0.5409 Accuracy_Dv: 0.8681 Loss_Generator: 0.4299
